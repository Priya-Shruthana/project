# %% [markdown]
# # Practice Session...

# %% [markdown]
# **1.Given the `Air Passengers` datasets perform the following operations.**
#
# a)Read the First six months of (Jan-Jun) data into the `first_half_df dataframe`.
#
# b)Fill any missing values with median strategy in the `air_df`.
#
# c)Create a column Year with values from `1949 to 1960` (both inclusive).

# %%
import pandas as pd
df=pd.read_csv("airline_passengers.csv")
df_half=df.iloc[:6]
df_half
# Out:
#       Month  Passengers
# 0  1/1/1949         112
# 1  1/2/1949         118
# 2  1/3/1949         132
# 3  1/4/1949         129
# 4  1/5/1949         121
# 5  1/6/1949         135

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df['Year']=range(1949-1960)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Year']=range(1949-1960)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
# ...

# %% [markdown]
# **2.For `Titanic dataset` spot the outliers using `Scatter plot` & `histogram plot`.**

# %%
import matplotlib.pyplot as plt
t=pd.read_csv("titanic2.csv")
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  ...   class    who adult_male  deck  embark_town alive  alone
# 0         0.0       3    male  22.0      1      0   7.2500  ...   Third    man       True   NaN  Southampton    no  False
# 1         1.0       1  female  38.0      1      0  71.2833  ...   First  woman      False     C    Cherbourg   yes  False
# 2         NaN       3  female   NaN      0      0   7.9250  ...   Third  woman      False   NaN  Southampton   yes   True
# 3         NaN       1  female   NaN      1      0  53.1000  ...   First  woman      False     C  Southampton   yes  False
# 4         0.0       3    male  35.0      0      0   8.0500  ...   Third    man       True   NaN  Southampton    no   True
# ..        ...     ...     ...   ...    ...    ...      ...  ...     ...    ...        ...   ...          ...   ...    ...
# 886       0.0       2    male  27.0      0      0  13.0000  ...  Second    man       True   NaN  Southampton    no   True
# ...

# %%
t.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  ...  class    who  adult_male   deck  embark_town  alive  alone
# 0       False   False  False  False  False  False  False  ...  False  False       False   True        False  False  False
# 1       False   False  False  False  False  False  False  ...  False  False       False  False        False  False  False
# 2        True   False  False   True  False  False  False  ...  False  False       False   True        False  False  False
# 3        True   False  False   True  False  False  False  ...  False  False       False  False        False  False  False
# 4       False   False  False  False  False  False  False  ...  False  False       False   True        False  False  False
# ..        ...     ...    ...    ...    ...    ...    ...  ...    ...    ...         ...    ...          ...    ...    ...
# 886     False   False  False  False  False  False  False  ...  False  False       False   True        False  False  False
# ...

# %%
plt.scatter(t['age'],t['fare'])
pltxlabel("Age")
plt.ylabel("Fare")
plt.title("Scatter plot. to detect outliers")
plt.show()

# %%
plt.hist('age','fare')
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Histogram to detect outliers")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.hist('age','fare')
#       2 plt.xlabel("Age")
#       3 plt.ylabel("Fare")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2618, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2612 @_copy_docstring_and_deprecators(Axes.hist)
#    2613 def hist(
#    2614         x, bins=None, range=None, density=False, weights=None,
#    2615         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2616         orientation='vertical', rwidth=None, log=False, color=None,
#    2617         label=None, stacked=False, *, data=None, **kwargs):
# -> 2618     return gca().hist(
#    2619         x, bins=bins, range=range, density=density, weights=weights,
# ...
